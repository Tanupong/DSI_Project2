# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, PolynomialFeatures,OneHotEncoder,LabelEncoder
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet,RidgeCV,LassoCV,ElasticNetCV
from sklearn import metrics

# %% [markdown]
# ## Import Data

# %%
#load train_cleaned.csv
train = pd.read_csv('../datasets/train_cleaned.csv')
train.head()
# Out:
#    ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# 0           60        RL       69.0552     13517   Pave  None       IR1
# 1           60        RL       43.0000     11492   Pave  None       IR1
# 2           20        RL       68.0000      7922   Pave  None       Reg
# 3           60        RL       73.0000      9802   Pave  None       Reg
# 4           50        RL       82.0000     14235   Pave  None       IR1
#
#   land_contour utilities lot_config  ... pool_area pool_qc fence misc_feature  \
# 0          Lvl    AllPub    CulDSac  ...         0    None  None         None
# 1          Lvl    AllPub    CulDSac  ...         0    None  None         None
# 2          Lvl    AllPub     Inside  ...         0    None  None         None
# 3          Lvl    AllPub     Inside  ...         0    None  None         None
# 4          Lvl    AllPub     Inside  ...         0    None  None         None
#
#   misc_val mo_sold  yr_sold  sale_type  saleprice  age_garage
# 0        0       3     2010        WD      130500        34.0
# 1        0       4     2009        WD      220000        12.0
# 2        0       1     2010        WD      109000        57.0
# 3        0       4     2010        WD      174000         3.0
# 4        0       3     2010        WD      138500        53.0
#
# [5 rows x 79 columns]

# %%
test = pd.read_csv('../datasets/test_cleaned.csv')
test.head()
# Out:
#    ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# 0          190        RM       69.0000      9142   Pave  Grvl       Reg
# 1           90        RL       69.0552      9662   Pave  None       IR1
# 2           60        RL       58.0000     17104   Pave  None       IR1
# 3           30        RM       60.0000      8520   Pave  None       Reg
# 4           20        RL       69.0552      9500   Pave  None       IR1
#
#   land_contour utilities lot_config  ... screen_porch pool_area pool_qc fence  \
# 0          Lvl    AllPub     Inside  ...            0         0    None  None
# 1          Lvl    AllPub     Inside  ...            0         0    None  None
# 2          Lvl    AllPub     Inside  ...            0         0    None  None
# 3          Lvl    AllPub     Inside  ...            0         0    None  None
# 4          Lvl    AllPub     Inside  ...          185         0    None  None
#
#   misc_feature misc_val  mo_sold  yr_sold  sale_type  age_garage
# 0         None        0        4     2006        WD         96.0
# 1         None        0        8     2006        WD         29.0
# 2         None        0        9     2006        New         0.0
# 3         None        0        7     2007        WD         72.0
# 4         None        0        7     2009        WD         46.0
#
# [5 rows x 78 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, PolynomialFeatures,OneHotEncoder,LabelEncoder
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet,RidgeCV,LassoCV,ElasticNetCV
from sklearn import metrics


## Import Data

#load train_cleaned.csv
train = pd.read_csv('../datasets/train_cleaned.csv')
train.head()

test = pd.read_csv('../datasets/test_cleaned.csv')
test.head()

# %% [markdown]
# ## 0:Baseline model

# %%
#create submit dataframe, get ID from test and assign Saleprice as mean
submit = test[['id']].rename(columns={'id':'Id'})
submit['SalePrice'] = train['saleprice'].mean()
submit.head()
# Out:
#      Id      SalePrice
# 0  2658  181469.701609
# 1  2718  181469.701609
# 2  2414  181469.701609
# 3  1989  181469.701609
# 4   625  181469.701609

# %%
#write submit to csv
submit.to_csv('../Model/0_baseline_model.csv',index=False)

# %% [markdown]
# ## 1: All features model

# %%
##

# %% [markdown]
# ## 2: All numeric model

# %%
##
