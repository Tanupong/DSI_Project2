# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet,RidgeCV,LassoCV,ElasticNetCV
from sklearn import metrics

# %% [markdown]
# ## Import Data

# %%
#load train.csv to dataframe
train = pd.read_csv('../datasets/train.csv')
train.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
# 2       Reg          Lvl  ...            0         0     NaN   NaN
# 3       Reg          Lvl  ...            0         0     NaN   NaN
# 4       IR1          Lvl  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# 0          NaN        0       3    2010        WD      130500
# 1          NaN        0       4    2009        WD      220000
# 2          NaN        0       1    2010        WD      109000
# 3          NaN        0       4    2010        WD      174000
# 4          NaN        0       3    2010        WD      138500
#
# [5 rows x 81 columns]

# %%
train.shape
# Out:
# (2051, 81)

# %%
train.columns
# Out:
# Index(['Id', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
#        'Fireplaces', 'Fireplace Qu', 'Garage Type', 'Garage Yr Blt',
#        'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual',
#        'Garage Cond', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
#        'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Pool QC',
#        'Fence', 'Misc Feature', 'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type',
#        'SalePrice'],
#       dtype='object')

# %%
#load test.csv to dataframe
test = pd.read_csv('../datasets/test.csv')
test.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour  ... 3Ssn Porch Screen Porch Pool Area Pool QC  \
# 0  Grvl       Reg          Lvl  ...          0            0         0     NaN
# 1   NaN       IR1          Lvl  ...          0            0         0     NaN
# 2   NaN       IR1          Lvl  ...          0            0         0     NaN
# 3   NaN       Reg          Lvl  ...          0            0         0     NaN
# 4   NaN       IR1          Lvl  ...          0          185         0     NaN
#
#   Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type
# 0   NaN          NaN        0       4     2006        WD
# 1   NaN          NaN        0       8     2006        WD
# 2   NaN          NaN        0       9     2006        New
# 3   NaN          NaN        0       7     2007        WD
# 4   NaN          NaN        0       7     2009        WD
#
# [5 rows x 80 columns]

# %%
test.shape
# Out:
# (879, 80)

# %%
#make column name lowercase and replace space with _
train.columns = train.columns.str.lower().str.replace(" ","_")
test.columns = test.columns.str.lower().str.replace(" ","_")

# %%
train.columns
# Out:
# Index(['id', 'pid', 'ms_subclass', 'ms_zoning', 'lot_frontage', 'lot_area',
#        'street', 'alley', 'lot_shape', 'land_contour', 'utilities',
#        'lot_config', 'land_slope', 'neighborhood', 'condition_1',
#        'condition_2', 'bldg_type', 'house_style', 'overall_qual',
#        'overall_cond', 'year_built', 'year_remod/add', 'roof_style',
#        'roof_matl', 'exterior_1st', 'exterior_2nd', 'mas_vnr_type',
#        'mas_vnr_area', 'exter_qual', 'exter_cond', 'foundation', 'bsmt_qual',
#        'bsmt_cond', 'bsmt_exposure', 'bsmtfin_type_1', 'bsmtfin_sf_1',
#        'bsmtfin_type_2', 'bsmtfin_sf_2', 'bsmt_unf_sf', 'total_bsmt_sf',
#        'heating', 'heating_qc', 'central_air', 'electrical', '1st_flr_sf',
#        '2nd_flr_sf', 'low_qual_fin_sf', 'gr_liv_area', 'bsmt_full_bath',
#        'bsmt_half_bath', 'full_bath', 'half_bath', 'bedroom_abvgr',
#        'kitchen_abvgr', 'kitchen_qual', 'totrms_abvgrd', 'functional',
#        'fireplaces', 'fireplace_qu', 'garage_type', 'garage_yr_blt',
#        'garage_finish', 'garage_cars', 'garage_area', 'garage_qual',
#        'garage_cond', 'paved_drive', 'wood_deck_sf', 'open_porch_sf',
#        'enclosed_porch', '3ssn_porch', 'screen_porch', 'pool_area', 'pool_qc',
#        'fence', 'misc_feature', 'misc_val', 'mo_sold', 'yr_sold', 'sale_type',
#        'saleprice'],
#       dtype='object')

# %% [markdown]
# ## Data cleaning

# %%
#check for null in train data
train.isnull().sum()[train.isnull().sum()>0]
# Out:
# lot_frontage       330
# alley             1911
# mas_vnr_type        22
# mas_vnr_area        22
# bsmt_qual           55
# bsmt_cond           55
# bsmt_exposure       58
# bsmtfin_type_1      55
# bsmtfin_sf_1         1
# bsmtfin_type_2      56
# bsmtfin_sf_2         1
# bsmt_unf_sf          1
# total_bsmt_sf        1
# bsmt_full_bath       2
# bsmt_half_bath       2
# fireplace_qu      1000
# garage_type        113
# garage_yr_blt      114
# garage_finish      114
# garage_cars          1
# garage_area          1
# garage_qual        114
# garage_cond        114
# pool_qc           2042
# fence             1651
# misc_feature      1986
# dtype: int64

# %%
#check for null in test data
test.isnull().sum()[test.isnull().sum()>0]
# Out:
# lot_frontage      160
# alley             821
# mas_vnr_type        1
# mas_vnr_area        1
# bsmt_qual          25
# bsmt_cond          25
# bsmt_exposure      25
# bsmtfin_type_1     25
# bsmtfin_type_2     25
# electrical          1
# fireplace_qu      422
# garage_type        44
# garage_yr_blt      45
# garage_finish      45
# garage_qual        45
# garage_cond        45
# pool_qc           875
# fence             707
# misc_feature      838
# dtype: int64

# %% [markdown]
# **Investigate by each columns**: lot_frontage

# %%
#Check for house with lot frontage =0
train[train['lot_frontage'] ==0]
# Out:
# Empty DataFrame
# Columns: [id, pid, ms_subclass, ms_zoning, lot_frontage, lot_area, street, alley, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, fireplace_qu, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, pool_qc, fence, misc_feature, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []
#
# [0 rows x 81 columns]

# %% [markdown]
# This is to check whether there is a house with no lot frontage at all. However, there is almost no chance that the house will not have lot frontage. Thus, we will not fill this null with zero

# %%
#Check for distribution
train['lot_frontage'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Seeing some outlier

# %%
#check relation ship between lot_frontage and saleprice
sns.scatterplot(data=train,x='lot_frontage',y='saleprice')
# Out:
# <AxesSubplot:xlabel='lot_frontage', ylabel='saleprice'>

# %%
#this might be outlier
train[train['lot_frontage']>300]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 960   1499  908154235           60        RL         313.0     63887   Pave
# 1335  1266  535427070           20        RL         313.0     27650   Pave
#
#      alley lot_shape land_contour  ... screen_porch pool_area pool_qc fence  \
# 960    NaN       IR3          Bnk  ...            0       480      Gd   NaN
# 1335   NaN       IR2          HLS  ...            0         0     NaN   NaN
#
#      misc_feature misc_val mo_sold yr_sold  sale_type  saleprice
# 960           NaN        0       1    2008        New     160000
# 1335          NaN        0      11    2008        WD      242000
#
# [2 rows x 81 columns]

# %%
#check relation ship between lot_frontage and lot_area
sns.scatterplot(data=train,x='lot_frontage',y='lot_area')
# Out:
# <AxesSubplot:xlabel='lot_frontage', ylabel='lot_area'>

# %%
#fill null in lot_frontage with mean: for both train and test data
lot_frontage_mean = train['lot_frontage'].mean()
train['lot_frontage'] = [x if x>0 else lot_frontage_mean for x in train['lot_frontage']]
test['lot_frontage'] = [x if x>0 else lot_frontage_mean for x in test['lot_frontage']]
train.isnull().sum()[train.isnull().sum()>0]
# Out:
# alley             1911
# mas_vnr_type        22
# mas_vnr_area        22
# bsmt_qual           55
# bsmt_cond           55
# bsmt_exposure       58
# bsmtfin_type_1      55
# bsmtfin_sf_1         1
# bsmtfin_type_2      56
# bsmtfin_sf_2         1
# bsmt_unf_sf          1
# total_bsmt_sf        1
# bsmt_full_bath       2
# bsmt_half_bath       2
# fireplace_qu      1000
# garage_type        113
# garage_yr_blt      114
# garage_finish      114
# garage_cars          1
# garage_area          1
# garage_qual        114
# garage_cond        114
# pool_qc           2042
# fence             1651
# misc_feature      1986
# dtype: int64

# %%
test.isnull().sum()[test.isnull().sum()>0]
# Out:
# alley             821
# mas_vnr_type        1
# mas_vnr_area        1
# bsmt_qual          25
# bsmt_cond          25
# bsmt_exposure      25
# bsmtfin_type_1     25
# bsmtfin_type_2     25
# electrical          1
# fireplace_qu      422
# garage_type        44
# garage_yr_blt      45
# garage_finish      45
# garage_qual        45
# garage_cond        45
# pool_qc           875
# fence             707
# misc_feature      838
# dtype: int64

# %%
#decide to drop lot_frontage >300
train = train[train['lot_frontage']<300]
sns.scatterplot(data=train,x='lot_frontage',y='saleprice')
# Out:
# <AxesSubplot:xlabel='lot_frontage', ylabel='saleprice'>

# %%
train.shape
# Out:
# (2049, 81)

# %% [markdown]
# **next column is alley**

# %%
train['alley'].dtypes
# Out:
# dtype('O')

# %%
train['alley'].value_counts() #looking in dic, NA = no alley access
#fill na with with None
# Out:
# Grvl    85
# Pave    55
# Name: alley, dtype: int64

# %%
train['alley'] = train['alley'].fillna('None')
test['alley'] = test['alley'].fillna('None')

# %%
train
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 0      109  533352170           60        RL       69.0552     13517   Pave
# 1      544  531379050           60        RL       43.0000     11492   Pave
# 2      153  535304180           20        RL       68.0000      7922   Pave
# 3      318  916386060           60        RL       73.0000      9802   Pave
# 4      255  906425045           50        RL       82.0000     14235   Pave
# ...    ...        ...          ...       ...           ...       ...    ...
# 2046  1587  921126030           20        RL       79.0000     11449   Pave
# 2047   785  905377130           30        RL       69.0552     12342   Pave
# 2048   916  909253010           50        RL       57.0000      7558   Pave
# 2049   639  535179160           20        RL       80.0000     10400   Pave
# 2050    10  527162130           60        RL       60.0000      7500   Pave
#
#      alley lot_shape land_contour  ... screen_porch pool_area pool_qc fence  \
# 0     None       IR1          Lvl  ...            0         0     NaN   NaN
# 1     None       IR1          Lvl  ...            0         0     NaN   NaN
# 2     None       Reg          Lvl  ...            0         0     NaN   NaN
# 3     None       Reg          Lvl  ...            0         0     NaN   NaN
# 4     None       IR1          Lvl  ...            0         0     NaN   NaN
# ...    ...       ...          ...  ...          ...       ...     ...   ...
# 2046  None       IR1          HLS  ...            0         0     NaN   NaN
# 2047  None       IR1          Lvl  ...            0         0     NaN   NaN
# 2048  None       Reg          Bnk  ...            0         0     NaN   NaN
# 2049  None       Reg          Lvl  ...            0         0     NaN   NaN
# 2050  None       Reg          Lvl  ...            0         0     NaN   NaN
#
#      misc_feature misc_val mo_sold yr_sold  sale_type  saleprice
# 0             NaN        0       3    2010        WD      130500
# 1             NaN        0       4    2009        WD      220000
# 2             NaN        0       1    2010        WD      109000
# 3             NaN        0       4    2010        WD      174000
# 4             NaN        0       3    2010        WD      138500
# ...           ...      ...     ...     ...        ...        ...
# 2046          NaN        0       1    2008        WD      298751
# 2047          NaN        0       3    2009        WD       82500
# 2048          NaN        0       3    2009        WD      177000
# 2049          NaN        0      11    2009        WD      144000
# 2050          NaN        0       6    2010        WD      189000
#
# [2049 rows x 81 columns]

# %%
test.isnull().sum()[test.isnull().sum()>0]
# Out:
# mas_vnr_type        1
# mas_vnr_area        1
# bsmt_qual          25
# bsmt_cond          25
# bsmt_exposure      25
# bsmtfin_type_1     25
# bsmtfin_type_2     25
# electrical          1
# fireplace_qu      422
# garage_type        44
# garage_yr_blt      45
# garage_finish      45
# garage_qual        45
# garage_cond        45
# pool_qc           875
# fence             707
# misc_feature      838
# dtype: int64

# %%
train.shape
# Out:
# (2049, 81)

# %% [markdown]
# **next column is mas_vnr_type,mas_vnr_area**

# %%
train['mas_vnr_type'].dtypes
# Out:
# dtype('O')

# %%
train['mas_vnr_type'].value_counts()
# Out:
# None       1217
# BrkFace     630
# Stone       167
# BrkCmn       13
# Name: mas_vnr_type, dtype: int64

# %%
train[train['mas_vnr_type'].isnull()][['mas_vnr_type','mas_vnr_area']]
# Out:
#      mas_vnr_type  mas_vnr_area
# 22            NaN           NaN
# 41            NaN           NaN
# 86            NaN           NaN
# 212           NaN           NaN
# 276           NaN           NaN
# 338           NaN           NaN
# 431           NaN           NaN
# 451           NaN           NaN
# 591           NaN           NaN
# 844           NaN           NaN
# 913           NaN           NaN
# 939           NaN           NaN
# 1025          NaN           NaN
# 1244          NaN           NaN
# 1306          NaN           NaN
# 1430          NaN           NaN
# 1434          NaN           NaN
# 1606          NaN           NaN
# 1699          NaN           NaN
# 1815          NaN           NaN
# 1820          NaN           NaN
# 1941          NaN           NaN

# %%
train['mas_vnr_area'].plot(kind='hist')
train['mas_vnr_area'].value_counts()[[0]]
# Out:
# 0    1215
# Name: mas_vnr_area, dtype: int64

# %%
train[train['mas_vnr_area'] ==0][['mas_vnr_type','mas_vnr_area']]
# Out:
#      mas_vnr_type  mas_vnr_area
# 2            None           0.0
# 3            None           0.0
# 4            None           0.0
# 5            None           0.0
# 8            None           0.0
# ...           ...           ...
# 2046         None           0.0
# 2047         None           0.0
# 2048         None           0.0
# 2049         None           0.0
# 2050         None           0.0
#
# [1215 rows x 2 columns]

# %% [markdown]
# Above is the process to make sure that if mas_vnr_type is null, mas_vnr_area is also null
#
# From this, I will infer that when both columns are null, it means none and the area should be 0

# %%
#fill na with none and 0
train['mas_vnr_type'] = train['mas_vnr_type'].fillna('None')
train['mas_vnr_area'] = train['mas_vnr_area'].fillna(0)
test['mas_vnr_type'] = test['mas_vnr_type'].fillna('None')
test['mas_vnr_area'] = test['mas_vnr_area'].fillna(0)

# %%
train.isnull().sum()[train.isnull().sum()>0]
# Out:
# bsmt_qual           55
# bsmt_cond           55
# bsmt_exposure       58
# bsmtfin_type_1      55
# bsmtfin_sf_1         1
# bsmtfin_type_2      56
# bsmtfin_sf_2         1
# bsmt_unf_sf          1
# total_bsmt_sf        1
# bsmt_full_bath       2
# bsmt_half_bath       2
# fireplace_qu      1000
# garage_type        113
# garage_yr_blt      114
# garage_finish      114
# garage_cars          1
# garage_area          1
# garage_qual        114
# garage_cond        114
# pool_qc           2041
# fence             1649
# misc_feature      1984
# dtype: int64

# %%
test.isnull().sum()[test.isnull().sum()>0]
# Out:
# bsmt_qual          25
# bsmt_cond          25
# bsmt_exposure      25
# bsmtfin_type_1     25
# bsmtfin_type_2     25
# electrical          1
# fireplace_qu      422
# garage_type        44
# garage_yr_blt      45
# garage_finish      45
# garage_qual        45
# garage_cond        45
# pool_qc           875
# fence             707
# misc_feature      838
# dtype: int64

# %% [markdown]
# **next column is basement relate**

# %%
#select column with bmst related
[col for col in train.columns if 'bsmt' in col]
# Out:
# ['bsmt_qual',
#  'bsmt_cond',
#  'bsmt_exposure',
#  'bsmtfin_type_1',
#  'bsmtfin_sf_1',
#  'bsmtfin_type_2',
#  'bsmtfin_sf_2',
#  'bsmt_unf_sf',
#  'total_bsmt_sf',
#  'bsmt_full_bath',
#  'bsmt_half_bath']

# %%
#investigate null by filtering bsmt_exposure is null
bsmt = [col for col in train.columns if 'bsmt' in col]
train[train['bsmt_exposure'].isnull()][bsmt]
# Out:
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 12         NaN       NaN           NaN            NaN           0.0
# 93         NaN       NaN           NaN            NaN           0.0
# 114        NaN       NaN           NaN            NaN           0.0
# 146        NaN       NaN           NaN            NaN           0.0
# 183        NaN       NaN           NaN            NaN           0.0
# 240        NaN       NaN           NaN            NaN           0.0
# 249        NaN       NaN           NaN            NaN           0.0
# 256        NaN       NaN           NaN            NaN           0.0
# 390        NaN       NaN           NaN            NaN           0.0
# 437        NaN       NaN           NaN            NaN           0.0
# 485        NaN       NaN           NaN            NaN           0.0
# 499        NaN       NaN           NaN            NaN           0.0
# 514        NaN       NaN           NaN            NaN           0.0
# 580        NaN       NaN           NaN            NaN           0.0
# 581        NaN       NaN           NaN            NaN           0.0
# 616        NaN       NaN           NaN            NaN           0.0
# 635        NaN       NaN           NaN            NaN           0.0
# 642        NaN       NaN           NaN            NaN           0.0
# 696        NaN       NaN           NaN            NaN           0.0
# 700        NaN       NaN           NaN            NaN           0.0
# 737        NaN       NaN           NaN            NaN           0.0
# 772        NaN       NaN           NaN            NaN           0.0
# 790        NaN       NaN           NaN            NaN           0.0
# 794        NaN       NaN           NaN            NaN           0.0
# 924        NaN       NaN           NaN            NaN           0.0
# 933        NaN       NaN           NaN            NaN           0.0
# 954        NaN       NaN           NaN            NaN           0.0
# 1007       NaN       NaN           NaN            NaN           0.0
# 1022       NaN       NaN           NaN            NaN           0.0
# 1049       NaN       NaN           NaN            NaN           0.0
# 1089       NaN       NaN           NaN            NaN           0.0
# 1098       NaN       NaN           NaN            NaN           0.0
# 1125       NaN       NaN           NaN            NaN           0.0
# 1157       NaN       NaN           NaN            NaN           0.0
# 1211       NaN       NaN           NaN            NaN           0.0
# 1222       NaN       NaN           NaN            NaN           0.0
# 1252       NaN       NaN           NaN            NaN           0.0
# 1256       NaN       NaN           NaN            NaN           0.0
# 1270       NaN       NaN           NaN            NaN           0.0
# 1327       NaN       NaN           NaN            NaN           NaN
# 1331       NaN       NaN           NaN            NaN           0.0
# 1377       NaN       NaN           NaN            NaN           0.0
# 1387       NaN       NaN           NaN            NaN           0.0
# 1428       NaN       NaN           NaN            NaN           0.0
# 1456        Gd        TA           NaN            Unf           0.0
# 1481       NaN       NaN           NaN            NaN           0.0
# 1547        Gd        TA           NaN            Unf           0.0
# 1594       NaN       NaN           NaN            NaN           0.0
# 1620       NaN       NaN           NaN            NaN           0.0
# 1681       NaN       NaN           NaN            NaN           0.0
# 1684       NaN       NaN           NaN            NaN           0.0
# 1686       NaN       NaN           NaN            NaN           0.0
# 1859       NaN       NaN           NaN            NaN           0.0
# 1875       NaN       NaN           NaN            NaN           0.0
# 1889       NaN       NaN           NaN            NaN           0.0
# 1933       NaN       NaN           NaN            NaN           0.0
# 1997        Gd        TA           NaN            Unf           0.0
# 2010       NaN       NaN           NaN            NaN           0.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  bsmt_full_bath  \
# 12              NaN           0.0          0.0            0.0             0.0
# 93              NaN           0.0          0.0            0.0             0.0
# 114             NaN           0.0          0.0            0.0             0.0
# 146             NaN           0.0          0.0            0.0             0.0
# 183             NaN           0.0          0.0            0.0             0.0
# 240             NaN           0.0          0.0            0.0             0.0
# 249             NaN           0.0          0.0            0.0             0.0
# 256             NaN           0.0          0.0            0.0             0.0
# 390             NaN           0.0          0.0            0.0             0.0
# 437             NaN           0.0          0.0            0.0             0.0
# 485             NaN           0.0          0.0            0.0             0.0
# 499             NaN           0.0          0.0            0.0             0.0
# 514             NaN           0.0          0.0            0.0             0.0
# 580             NaN           0.0          0.0            0.0             0.0
# 581             NaN           0.0          0.0            0.0             0.0
# 616             NaN           0.0          0.0            0.0             NaN
# 635             NaN           0.0          0.0            0.0             0.0
# 642             NaN           0.0          0.0            0.0             0.0
# 696             NaN           0.0          0.0            0.0             0.0
# 700             NaN           0.0          0.0            0.0             0.0
# 737             NaN           0.0          0.0            0.0             0.0
# 772             NaN           0.0          0.0            0.0             0.0
# 790             NaN           0.0          0.0            0.0             0.0
# 794             NaN           0.0          0.0            0.0             0.0
# 924             NaN           0.0          0.0            0.0             0.0
# 933             NaN           0.0          0.0            0.0             0.0
# 954             NaN           0.0          0.0            0.0             0.0
# 1007            NaN           0.0          0.0            0.0             0.0
# 1022            NaN           0.0          0.0            0.0             0.0
# 1049            NaN           0.0          0.0            0.0             0.0
# 1089            NaN           0.0          0.0            0.0             0.0
# 1098            NaN           0.0          0.0            0.0             0.0
# 1125            NaN           0.0          0.0            0.0             0.0
# 1157            NaN           0.0          0.0            0.0             0.0
# 1211            NaN           0.0          0.0            0.0             0.0
# 1222            NaN           0.0          0.0            0.0             0.0
# 1252            NaN           0.0          0.0            0.0             0.0
# 1256            NaN           0.0          0.0            0.0             0.0
# 1270            NaN           0.0          0.0            0.0             0.0
# 1327            NaN           NaN          NaN            NaN             NaN
# 1331            NaN           0.0          0.0            0.0             0.0
# 1377            NaN           0.0          0.0            0.0             0.0
# 1387            NaN           0.0          0.0            0.0             0.0
# 1428            NaN           0.0          0.0            0.0             0.0
# 1456            Unf           0.0        725.0          725.0             0.0
# 1481            NaN           0.0          0.0            0.0             0.0
# 1547            Unf           0.0       1595.0         1595.0             0.0
# 1594            NaN           0.0          0.0            0.0             0.0
# 1620            NaN           0.0          0.0            0.0             0.0
# 1681            NaN           0.0          0.0            0.0             0.0
# 1684            NaN           0.0          0.0            0.0             0.0
# 1686            NaN           0.0          0.0            0.0             0.0
# 1859            NaN           0.0          0.0            0.0             0.0
# 1875            NaN           0.0          0.0            0.0             0.0
# 1889            NaN           0.0          0.0            0.0             0.0
# 1933            NaN           0.0          0.0            0.0             0.0
# 1997            Unf           0.0        936.0          936.0             0.0
# 2010            NaN           0.0          0.0            0.0             0.0
#
#       bsmt_half_bath
# 12               0.0
# 93               0.0
# 114              0.0
# 146              0.0
# 183              0.0
# 240              0.0
# 249              0.0
# 256              0.0
# 390              0.0
# 437              0.0
# 485              0.0
# 499              0.0
# 514              0.0
# 580              0.0
# 581              0.0
# 616              NaN
# 635              0.0
# 642              0.0
# 696              0.0
# 700              0.0
# 737              0.0
# 772              0.0
# 790              0.0
# 794              0.0
# 924              0.0
# 933              0.0
# 954              0.0
# 1007             0.0
# 1022             0.0
# 1049             0.0
# 1089             0.0
# 1098             0.0
# 1125             0.0
# 1157             0.0
# 1211             0.0
# 1222             0.0
# 1252             0.0
# 1256             0.0
# 1270             0.0
# 1327             NaN
# 1331             0.0
# 1377             0.0
# 1387             0.0
# 1428             0.0
# 1456             0.0
# 1481             0.0
# 1547             0.0
# 1594             0.0
# 1620             0.0
# 1681             0.0
# 1684             0.0
# 1686             0.0
# 1859             0.0
# 1875             0.0
# 1889             0.0
# 1933             0.0
# 1997             0.0
# 2010             0.0

# %% [markdown]
# for all of these columns NA mean no basement which will result in area = 0, Thus, I will fill nan with 'None' and 0

# %%
#fill na with 0 and none
def fill_na_test_train(columns):
    '''fill nan in train data and test data with 
    - None if dtypes is object
    - 0 if dtypes is float64/int64
    columns is accepted in list
    '''
    for col in columns:
        if train[col].dtypes == 'O':
            train[col] = train[col].fillna('None')
        else:
            train[col] = train[col].fillna(0)

    for col in columns:
        if test[col].dtypes == 'O':
            test[col] = test[col].fillna('None')
        else:
            test[col] = test[col].fillna(0)
    pass

# %%
fill_na_test_train(bsmt)

# %%
train.isnull().sum()[train.isnull().sum()>0]
# Out:
# fireplace_qu     1000
# garage_type       113
# garage_yr_blt     114
# garage_finish     114
# garage_cars         1
# garage_area         1
# garage_qual       114
# garage_cond       114
# pool_qc          2041
# fence            1649
# misc_feature     1984
# dtype: int64

# %%
test.isnull().sum()[test.isnull().sum()>0]
# Out:
# electrical         1
# fireplace_qu     422
# garage_type       44
# garage_yr_blt     45
# garage_finish     45
# garage_qual       45
# garage_cond       45
# pool_qc          875
# fence            707
# misc_feature     838
# dtype: int64

# %% [markdown]
# **fireplace_qu**

# %%
#fill na with 'None'
train['fireplace_qu'] = train['fireplace_qu'].fillna('None')
test['fireplace_qu'] = test['fireplace_qu'].fillna('None')

# %%
train.isnull().sum()[train.isnull().sum()>0]
# Out:
# garage_type       113
# garage_yr_blt     114
# garage_finish     114
# garage_cars         1
# garage_area         1
# garage_qual       114
# garage_cond       114
# pool_qc          2041
# fence            1649
# misc_feature     1984
# dtype: int64

# %%
test.isnull().sum()[test.isnull().sum()>0]
# Out:
# electrical         1
# garage_type       44
# garage_yr_blt     45
# garage_finish     45
# garage_qual       45
# garage_cond       45
# pool_qc          875
# fence            707
# misc_feature     838
# dtype: int64

# %% [markdown]
# **Garage relate columns**

# %%
train.shape
# Out:
# (2049, 81)

# %%
garage = [col for col in train.columns if 'garage' in col]
garage
# Out:
# ['garage_type',
#  'garage_yr_blt',
#  'garage_finish',
#  'garage_cars',
#  'garage_area',
#  'garage_qual',
#  'garage_cond']

# %%
train[train['garage_cars'].isnull()][garage] #this is the only row that has type but no data on other columns
#So, assume that this is miscollected.
#drop this row
# Out:
#      garage_type  garage_yr_blt garage_finish  garage_cars  garage_area  \
# 1712      Detchd            NaN           NaN          NaN          NaN
#
#      garage_qual garage_cond
# 1712         NaN         NaN

# %%
train.drop(index=1712,inplace=True)

# %%
train.reset_index(inplace=True,drop=True) #reset index after drop

# %%
train.shape
# Out:
# (2048, 81)

# %%
train.isnull().sum()[train.isnull().sum()>0]
# Out:
# garage_type       113
# garage_yr_blt     113
# garage_finish     113
# garage_qual       113
# garage_cond       113
# pool_qc          2040
# fence            1649
# misc_feature     1983
# dtype: int64

# %%
train[garage].dtypes #fill na with none and 0 except for yr_blt
#for yr_blt, fill with yrsold+1 
#create new columns garage_age = yrsold - garage_yr_blt // for no garage , age = -1
#then drop garage_yr_blt column
# Out:
# garage_type       object
# garage_yr_blt    float64
# garage_finish     object
# garage_cars      float64
# garage_area      float64
# garage_qual       object
# garage_cond       object
# dtype: object

# %%
garage = [col for col in garage if col != 'garage_yr_blt']

# %%
#fill na with 0 and none
fill_na_test_train(garage)

# %%
train.isnull().sum()[train.isnull().sum()>0]
# Out:
# garage_yr_blt     113
# pool_qc          2040
# fence            1649
# misc_feature     1983
# dtype: int64

# %%
test.isnull().sum()[test.isnull().sum()>0]
# Out:
# electrical         1
# garage_yr_blt     45
# pool_qc          875
# fence            707
# misc_feature     838
# dtype: int64

# %%
#for yr_blt, fill with yrsold+1 
#create new columns garage_age = yrsold - garage_yr_blt // for no garage , age = -1
#then drop garage_yr_blt column
train['garage_yr_blt'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
train[train['garage_yr_blt'].isnull()][['garage_yr_blt','yr_sold']]
# Out:
#       garage_yr_blt  yr_sold
# 28              NaN     2007
# 53              NaN     2010
# 65              NaN     2007
# 79              NaN     2007
# 101             NaN     2007
# ...             ...      ...
# 1988            NaN     2010
# 2007            NaN     2006
# 2024            NaN     2006
# 2036            NaN     2007
# 2039            NaN     2006
#
# [113 rows x 2 columns]

# %%
train[train['garage_yr_blt']>train['yr_sold']][['garage_yr_blt','yr_sold']] #found this error
# Out:
#       garage_yr_blt  yr_sold
# 1697         2207.0     2007
# 1882         2008.0     2007

# %%
#set value to be 2007
train.at[1697,'garage_yr_blt'] = 2007
train.at[1882,'garage_yr_blt'] = 2007

# %%
train[train['garage_yr_blt']>train['yr_sold']][['garage_yr_blt','yr_sold']] #confirm that it's already fixed.
# Out:
# Empty DataFrame
# Columns: [garage_yr_blt, yr_sold]
# Index: []

# %%
#fill with yrsold+1 
train['garage_yr_blt']= train['garage_yr_blt'].fillna((train['yr_sold']+1))

# %%
train[train['garage_yr_blt']==train['yr_sold']+1][['garage_yr_blt','yr_sold']]
# Out:
#       garage_yr_blt  yr_sold
# 28           2008.0     2007
# 53           2011.0     2010
# 65           2008.0     2007
# 79           2008.0     2007
# 101          2008.0     2007
# ...             ...      ...
# 1988         2011.0     2010
# 2007         2007.0     2006
# 2024         2007.0     2006
# 2036         2008.0     2007
# 2039         2007.0     2006
#
# [113 rows x 2 columns]

# %%
train['age_garage'] = train['yr_sold'] - train['garage_yr_blt']
train['age_garage'].hist()
# Out:
# <AxesSubplot:>

# %%
train['age_garage'].value_counts()
# Out:
#  1.0      134
# -1.0      113
#  0.0      105
#  2.0       60
#  4.0       59
#          ...
#  91.0       1
#  109.0      1
#  99.0       1
#  114.0      1
#  113.0      1
# Name: age_garage, Length: 104, dtype: int64

# %%
#drop age_garace
train.drop(columns='garage_yr_blt',inplace=True)

# %%
#Check for error
test[test['garage_yr_blt']>test['yr_sold']][['garage_yr_blt','yr_sold']]
# Out:
# Empty DataFrame
# Columns: [garage_yr_blt, yr_sold]
# Index: []

# %%
#same for test data
test['garage_yr_blt']= test['garage_yr_blt'].fillna((test['yr_sold']+1))
test['age_garage'] = test['yr_sold'] - test['garage_yr_blt']
test.drop(columns='garage_yr_blt',inplace=True)

# %%
train.isnull().sum()[train.isnull().sum()>0]
# Out:
# pool_qc         2040
# fence           1649
# misc_feature    1983
# dtype: int64

# %%
test.isnull().sum()[test.isnull().sum()>0]
# Out:
# electrical        1
# pool_qc         875
# fence           707
# misc_feature    838
# dtype: int64

# %% [markdown]
# **pool_qc/fence/misc**

# %%
fill_na_test_train(['pool_qc','fence','misc_feature'])

# %%
train.isnull().sum()[train.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
test.isnull().sum()[test.isnull().sum()>0]
# Out:
# electrical    1
# dtype: int64

# %% [markdown]
# **for electical in test_data**

# %%
train['electrical'].value_counts()
# Out:
# SBrkr    1865
# FuseA     140
# FuseF      35
# FuseP       7
# Mix         1
# Name: electrical, dtype: int64

# %%
test['electrical'].value_counts()
# Out:
# SBrkr    814
# FuseA     48
# FuseF     15
# FuseP      1
# Name: electrical, dtype: int64

# %%
test['electrical'] = test['electrical'].fillna('None')

# %% [markdown]
# **Drop ID/PID columns since it has no values**

# %%
train.drop(columns=['id','pid'],inplace=True)
test.drop(columns=['pid'],inplace=True)

# %% [markdown]
# ## EDA

# %%
#Create correlation matrix
corr = train.corr()
corr.shape
# Out:
# (37, 37)

# %%
corr_sale = corr['saleprice'].sort_values()
corr_sale
# Out:
# age_garage        -0.441314
# enclosed_porch    -0.135338
# kitchen_abvgr     -0.125461
# overall_cond      -0.097566
# ms_subclass       -0.086982
# bsmt_half_bath    -0.045288
# low_qual_fin_sf   -0.041597
# yr_sold           -0.015360
# misc_val          -0.007372
# bsmtfin_sf_2       0.016451
# pool_area          0.025820
# mo_sold            0.031683
# 3ssn_porch         0.048747
# screen_porch       0.134631
# bedroom_abvgr      0.136701
# bsmt_unf_sf        0.191158
# 2nd_flr_sf         0.249497
# half_bath          0.283544
# bsmt_full_bath     0.283982
# lot_area           0.301923
# wood_deck_sf       0.327210
# open_porch_sf      0.335339
# lot_frontage       0.345965
# bsmtfin_sf_1       0.439351
# fireplaces         0.473064
# totrms_abvgrd      0.505837
# mas_vnr_area       0.506371
# full_bath          0.538268
# year_remod/add     0.550753
# year_built         0.572548
# 1st_flr_sf         0.632030
# garage_cars        0.648281
# total_bsmt_sf      0.651807
# garage_area        0.653962
# gr_liv_area        0.710253
# overall_qual       0.801996
# saleprice          1.000000
# Name: saleprice, dtype: float64

# %%
#filter for aba
corr_sale[np.abs(corr_sale)>0.4]
# Out:
# age_garage       -0.441314
# bsmtfin_sf_1      0.439351
# fireplaces        0.473064
# totrms_abvgrd     0.505837
# mas_vnr_area      0.506371
# full_bath         0.538268
# year_remod/add    0.550753
# year_built        0.572548
# 1st_flr_sf        0.632030
# garage_cars       0.648281
# total_bsmt_sf     0.651807
# garage_area       0.653962
# gr_liv_area       0.710253
# overall_qual      0.801996
# saleprice         1.000000
# Name: saleprice, dtype: float64

# %%
pairplot_col = [col for col in corr_sale[np.abs(corr_sale)>0.4].index if col!='saleprice']
pairplot_col
# Out:
# ['age_garage',
#  'bsmtfin_sf_1',
#  'fireplaces',
#  'totrms_abvgrd',
#  'mas_vnr_area',
#  'full_bath',
#  'year_remod/add',
#  'year_built',
#  '1st_flr_sf',
#  'garage_cars',
#  'total_bsmt_sf',
#  'garage_area',
#  'gr_liv_area',
#  'overall_qual']

# %%
#pairplot
for i in range(0,len(pairplot_col),3):
    sns.pairplot(data=train,y_vars=['saleprice'],x_vars=pairplot_col[i:i+3],diag_kind=None,height=4)

# %% [markdown]
# Found Outlier in gr_liv_area, bsmtfin_sf_1, 1st_flt_sf

# %%
train[train['gr_liv_area'] > 4000]
# Out:
#       ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# 1882           20        RL         128.0     39290   Pave  None       IR1
#
#      land_contour utilities lot_config  ... pool_area pool_qc fence  \
# 1882          Bnk    AllPub     Inside  ...         0    None  None
#
#      misc_feature misc_val mo_sold  yr_sold  sale_type  saleprice  age_garage
# 1882         Elev    17000      10     2007        New     183850         0.0
#
# [1 rows x 79 columns]

# %% [markdown]
# filter out this row

# %%
train = train[train['gr_liv_area'] < 4000]
sns.pairplot(data=train,y_vars=['saleprice'],x_vars=['gr_liv_area','bsmtfin_sf_1', '1st_flr_sf'],diag_kind=None,height=4)

# %%
train[train['1st_flr_sf'] > 4000]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, alley, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, fireplace_qu, garage_type, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, pool_qc, fence, misc_feature, misc_val, mo_sold, yr_sold, sale_type, saleprice, age_garage]
# Index: []
#
# [0 rows x 79 columns]

# %% [markdown]
# Outlier from these 3 columns is the same row!!

# %%
#overall qulity has good correlation, let's look at overall condition
plt.figure(figsize=(8,6))
sns.scatterplot(data=train,x='overall_cond',y='saleprice')
# Out:
# <AxesSubplot:xlabel='overall_cond', ylabel='saleprice'>

# %% [markdown]
# Many data point is in 5, make correlation low.

# %% [markdown]
# All of features mentioned above show correlation and maybe need to incorporate in the model late.

# %%
categorical_columns = [col for col in train.select_dtypes('object').columns]
numerical_columns = [col for col in train.columns if col not in categorical_columns]

# %%
for i in range(0,len(numerical_columns),3):
    sns.pairplot(data=train,y_vars=['saleprice'],x_vars=numerical_columns[i:i+3],diag_kind=None,height=3)

# %%
train[train['lot_area']>100000] # drop these 2 columns
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# 471           50        RL       69.0552    159000   Pave  None       IR2
# 694           20        RL       69.0552    115149   Pave  None       IR2
#
#     land_contour utilities lot_config  ... pool_area pool_qc fence  \
# 471          Low    AllPub    CulDSac  ...         0    None  None
# 694          Low    AllPub    CulDSac  ...         0    None  None
#
#     misc_feature misc_val mo_sold  yr_sold  sale_type  saleprice  age_garage
# 471         Shed      500       6     2007        WD      277000        49.0
# 694         None        0       6     2007        WD      302000        36.0
#
# [2 rows x 79 columns]

# %%
train = train[train['lot_area']<100000]

# %%
for i in range(0,len(numerical_columns),3):
    sns.pairplot(data=train,y_vars=['saleprice'],x_vars=numerical_columns[i:i+3],diag_kind=None,height=3)

# %% [markdown]
# ** now look at categorical data**

# %%
for i in range(0,len(categorical_columns),3):
    fig, (ax1, ax2,ax3) = plt.subplots(1,3,figsize=(15,5))
    sns.boxplot(data=train,y='saleprice',x=categorical_columns[i],ax=ax1)
    sns.boxplot(data=train,y='saleprice',x=categorical_columns[i+1],ax=ax2)
    sns.boxplot(data=train,y='saleprice',x=categorical_columns[i+2],ax=ax3)

# %% [markdown]
# Most feature show clear correlation with saleprice such as **'street'**, **'pool_qc'** ,**'exter_cond'** , **'exter_qual'** , etc.

# %% [markdown]
# ## write to csv

# %%
#write to csv
train.to_csv('../datasets/train_cleaned.csv',index=False)
test.to_csv('../datasets/test_cleaned.csv',index=False)

#move to next notebook  Project_02_02

# %%
test
# Out:
#        id  ms_subclass ms_zoning  lot_frontage  lot_area street alley  \
# 0    2658          190        RM       69.0000      9142   Pave  Grvl
# 1    2718           90        RL       69.0552      9662   Pave  None
# 2    2414           60        RL       58.0000     17104   Pave  None
# 3    1989           30        RM       60.0000      8520   Pave  None
# 4     625           20        RL       69.0552      9500   Pave  None
# ..    ...          ...       ...           ...       ...    ...   ...
# 874  1662           60        RL       80.0000      8000   Pave  None
# 875  1234           60        RL       90.0000     14670   Pave  None
# 876  1373           20        RL       55.0000      8250   Pave  None
# 877  1672           20        RL       60.0000      9000   Pave  None
# 878  1939           20        RL       70.0000      8400   Pave  None
#
#     lot_shape land_contour utilities  ... screen_porch pool_area pool_qc  \
# 0         Reg          Lvl    AllPub  ...            0         0    None
# 1         IR1          Lvl    AllPub  ...            0         0    None
# 2         IR1          Lvl    AllPub  ...            0         0    None
# 3         Reg          Lvl    AllPub  ...            0         0    None
# 4         IR1          Lvl    AllPub  ...          185         0    None
# ..        ...          ...       ...  ...          ...       ...     ...
# 874       Reg          Lvl    AllPub  ...            0         0    None
# 875       Reg          Lvl    AllPub  ...            0         0    None
# 876       Reg          Lvl    AllPub  ...            0         0    None
# 877       Reg          Lvl    AllPub  ...            0         0    None
# 878       Reg          Lvl    AllPub  ...            0         0    None
#
#      fence misc_feature misc_val mo_sold  yr_sold  sale_type  age_garage
# 0     None         None        0       4     2006        WD         96.0
# 1     None         None        0       8     2006        WD         29.0
# 2     None         None        0       9     2006        New         0.0
# 3     None         None        0       7     2007        WD         72.0
# 4     None         None        0       7     2009        WD         46.0
# ..     ...          ...      ...     ...      ...        ...         ...
# 874   None         None        0      11     2007        WD         33.0
# 875  MnPrv         None        0       8     2008        WD         42.0
# 876   None         None        0       8     2008        WD         40.0
# 877   GdWo         None        0       5     2007        WD         33.0
# 878   GdWo         None        0       3     2007        WD         52.0
#
# [879 rows x 79 columns]
